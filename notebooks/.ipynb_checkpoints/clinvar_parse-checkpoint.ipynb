# %%
from CADA.paths import DATA_DIRECTORY
import collections
import os
import pandas as pd
import re
import pickle

with open('../data/raw/ids/hpo_old_new.dict', 'rb') as handle:
    hpo_dict = pickle.load(handle)

with open('../data/raw/ids/hpo_id_name.dict', 'rb') as handle:
    hpo_id_name = pickle.load(handle)

with open('../data/raw/ids/gene_name_id.dict', 'rb') as handle:
    gene_name_id = pickle.load(handle)

# %% [markdown]
# ## 1. Parse clinvar 'Pathogenic' and 'Likely pathogenic' submissions from submission_summary.txt
#
# https://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/

# %%
# parse submissions from Clinvar submission summary
submission_summary ='../data/raw/clinvar/submission_summary.txt'
clinvar_summary_data = collections.defaultdict(dict)


# data cleaning, keep submissions with known'Pathogenic' and 'Likely pathogenic' mutations
with open(submission_summary, 'r') as infile:
        content = infile.read().splitlines()[16:]
        content = [x.split('\t') for x in content]
        for line in content:
            # parse case id, submitter, gene
            clinvar_patient =  'Patient:'+line[10].split('.')[0]
            submitter= line[9]
            gene = line[11]
            # parse case significance
            significance = line[1]
                
            # only include case with 'Pathogenic' and 'Likely pathogenic' significance
            if significance in ['Pathogenic', 'Likely pathogenic']:
                if gene != '-' and gene in gene_name_id:
                    clinvar_summary_data[clinvar_patient]['gene_id'] = gene_name_id[gene]
                    clinvar_summary_data[clinvar_patient]['submitter'] = submitter
                                     
                                       
df_submission = pd.DataFrame.from_dict(clinvar_summary_data, orient='index')

# %%
df_submission
# Out:
#                            gene_id  \
# Patient:SCV000020155   Entrez:9907
# Patient:SCV000020156   Entrez:9907
# Patient:SCV000020158  Entrez:55572
# Patient:SCV000680696  Entrez:55572
# Patient:SCV000020159  Entrez:55572
# ...                            ...
# Patient:SCV001164575  Entrez:57096
# Patient:SCV001164576  Entrez:57096
# Patient:SCV001164581   Entrez:1756
# Patient:SCV001164584   Entrez:4703
# Patient:SCV001164586  Entrez:57096
#
#                                                               submitter
# Patient:SCV000020155                                               OMIM
# Patient:SCV000020156                                               OMIM
# Patient:SCV000020158                                               OMIM
# Patient:SCV000680696                                             GeneDx
# Patient:SCV000020159                                               OMIM
# ...                                                                 ...
# Patient:SCV001164575  Broad Institute Rare Disease Group,Broad Insti...
# Patient:SCV001164576  Broad Institute Rare Disease Group,Broad Insti...
# Patient:SCV001164581  Broad Institute Rare Disease Group,Broad Insti...
# Patient:SCV001164584  Broad Institute Rare Disease Group,Broad Insti...
# Patient:SCV001164586  Broad Institute Rare Disease Group,Broad Insti...
#
# [165583 rows x 2 columns]

# %% [markdown]
# ## 2. Parse HPO terms from ClinVarFullRelease
#
# https://ftp.ncbi.nlm.nih.gov/pub/clinvar/xml/

# %%
# cmd = 'grep '^\s*<ClinVarAccession Acc="SCV\|^\s*<XRef.*ID="HP:' ClinVarFullRelease_2020-06.xml > full_release.txt'
# os.system(cmd)

# %%
full_release = 'full_release.txt'
clinvar_data = collections.defaultdict(dict)

out_tsv = 'clinvar_submissions.tsv'


with open(full_release, 'r') as infile:
        content = infile.read().split('ClinVarAccession')
        for i in content[1:]:
            if 'SCV' in i and 'HP:' in i:
                matchacc = re.match(' Acc="(SCV\d+)"', i)
                clinvar_patient = 'Patient:'+matchacc.group(1)
                hpo_ids = []
                hpo_names = []
                matchhpo = re.finditer('(HP:\d+)', i)
                for hpo in matchhpo:
                    hpo_ids.append(hpo_dict.get(hpo.group(), hpo.group()))
                    hpo_ids = list(set(hpo_ids))
                if len(hpo_ids) > 0 :
                    clinvar_data[clinvar_patient]['features'] = ','.join(hpo_ids)


df_full = pd.DataFrame.from_dict(clinvar_data, orient='index')
df_full
# Out:
#                                                                features
# Patient:SCV000045941                                         HP:0001627
# Patient:SCV000077558  HP:0000104,HP:0000707,HP:0000717,HP:0001263,HP...
# Patient:SCV000077566                   HP:0002311,HP:0002474,HP:0008619
# Patient:SCV000077569                                         HP:0001250
# Patient:SCV000077571                                         HP:0001263
# ...                                                                 ...
# Patient:SCV001430295                              HP:0000107,HP:0005562
# Patient:SCV001430296                              HP:0000107,HP:0005562
# Patient:SCV001430297                              HP:0000107,HP:0005562
# Patient:SCV001430888                              HP:0005584,HP:0000256
# Patient:SCV001430889                   HP:0005584,HP:0000256,HP:0012500
#
# [30701 rows x 1 columns]

# %%
df = pd.merge(df_full, df_submission, how = 'inner', left_index=True, right_index=True)
df
# Out:
#                                                                features  \
# Patient:SCV000148377  HP:0010535,HP:0001319,HP:0001263,HP:0000750,HP...
# Patient:SCV000148378  HP:0010535,HP:0001319,HP:0001263,HP:0000750,HP...
# Patient:SCV000148379  HP:0010535,HP:0001319,HP:0001263,HP:0000750,HP...
# Patient:SCV000189113  HP:0001249,HP:0001319,HP:0001263,HP:0000750,HP...
# Patient:SCV000189114        HP:0001263,HP:0000750,HP:0001319,HP:0001249
# ...                                                                 ...
# Patient:SCV001162809  HP:0000252,HP:0009109,HP:0001250,HP:0001263,HP...
# Patient:SCV001162814  HP:0001876,HP:0001653,HP:0000952,HP:0001250,HP...
# Patient:SCV001162819                              HP:0000112,HP:0000100
# Patient:SCV001162824                   HP:0002460,HP:0002093,HP:0007141
# Patient:SCV001162825                   HP:0002460,HP:0002093,HP:0007141
#
#                            gene_id  \
# Patient:SCV000148377  Entrez:27245
# Patient:SCV000148378  Entrez:27245
# Patient:SCV000148379  Entrez:27245
# Patient:SCV000189113   Entrez:5813
# Patient:SCV000189114   Entrez:5813
# ...                            ...
# Patient:SCV001162809   Entrez:3028
# Patient:SCV001162814   Entrez:8085
# Patient:SCV001162819  Entrez:51196
# Patient:SCV001162824  Entrez:79628
# Patient:SCV001162825  Entrez:79628
#
#                                                               submitter
# Patient:SCV000148377  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000148378  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000148379  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000189113  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000189114  Whole genome laboratory; Baylor College of Med...
# ...                                                                 ...
# Patient:SCV001162809  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162814  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162819  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162824  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162825  Institute of Human Genetics,Klinikum rechts de...
#
# [4494 rows x 3 columns]

# %% [markdown]
# ## 3. Remove submissions with identical features, gene and submitter

# %%
df_filtered_identical = df.drop_duplicates()
df_filtered_identical
# Out:
#                                                                features  \
# Patient:SCV000148377  HP:0010535,HP:0001319,HP:0001263,HP:0000750,HP...
# Patient:SCV000189113  HP:0001249,HP:0001319,HP:0001263,HP:0000750,HP...
# Patient:SCV000189114        HP:0001263,HP:0000750,HP:0001319,HP:0001249
# Patient:SCV000192942                                         HP:0002282
# Patient:SCV000193153                                         HP:0000365
# ...                                                                 ...
# Patient:SCV001162796        HP:0007183,HP:0012752,HP:0012748,HP:0040168
# Patient:SCV001162809  HP:0000252,HP:0009109,HP:0001250,HP:0001263,HP...
# Patient:SCV001162814  HP:0001876,HP:0001653,HP:0000952,HP:0001250,HP...
# Patient:SCV001162819                              HP:0000112,HP:0000100
# Patient:SCV001162824                   HP:0002460,HP:0002093,HP:0007141
#
#                            gene_id  \
# Patient:SCV000148377  Entrez:27245
# Patient:SCV000189113   Entrez:5813
# Patient:SCV000189114   Entrez:5813
# Patient:SCV000192942   Entrez:1641
# Patient:SCV000193153   Entrez:2706
# ...                            ...
# Patient:SCV001162796   Entrez:1181
# Patient:SCV001162809   Entrez:3028
# Patient:SCV001162814   Entrez:8085
# Patient:SCV001162819  Entrez:51196
# Patient:SCV001162824  Entrez:79628
#
#                                                               submitter
# Patient:SCV000148377  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000189113  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000189114  Whole genome laboratory; Baylor College of Med...
# Patient:SCV000192942  Genetic Services Laboratory, University of Chi...
# Patient:SCV000193153  Genetic Services Laboratory, University of Chi...
# ...                                                                 ...
# Patient:SCV001162796  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162809  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162814  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162819  Institute of Human Genetics,Klinikum rechts de...
# Patient:SCV001162824  Institute of Human Genetics,Klinikum rechts de...
#
# [2814 rows x 3 columns]
