# %%
from split import split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f29d90f339e5> in <module>()
# ----> 1 from split import split
#
# /home/peng/PycharmProjects/featurematch/src/featurematch/preprocessing/patients/split.py in <module>()
#       1 import os
# ----> 2 import pronto
#       3 from ...paths import DATA_DIRECTORY
#       4 from .reform import reform_f2g_fm, reform_f2g_tucases, reform_pedia
#       5
#
# ModuleNotFoundError: No module named 'pronto'
