# %%
import gensim
from gensim.models import Word2Vec
from node2vec import Node2Vec
import pandas as pd 

model = Word2Vec.load('annotation_all_triples_hpo.model')
lists = []
model.wv.most_similar('Marshall syndrome')
#model.wv.most_similar('Multiple congenital anomalies-hypotonia-seizures syndrome')

# a = model.wv.most_similar('HP:0005280', topn=2500)
# a_list = pd.DataFrame(a).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in a_list)
# lists.append(a_list)

# b = model.wv.most_similar('HP:0000175', topn=2500)
# b_list = pd.DataFrame(b).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in b_list)
# lists.append(b_list)

# c = model.wv.most_similar('HP:0000347', topn=2500)
# c_list = pd.DataFrame(c).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in c_list)
# lists.append(c_list)


# d = model.wv.most_similar('HP:0000545', topn=2500)
# d_list = pd.DataFrame(d).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in d_list)
# lists.append(d_list)

# e = model.wv.most_similar('HP:0000463', topn=2500)
# e_list = pd.DataFrame(e).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in e_list)
# lists.append(e_list)

# f = model.wv.most_similar('HP:0003196', topn=2500)
# f_list = pd.DataFrame(f).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in f_list)
# lists.append(f_list)

# # g = model.wv.most_similar('HP:0000201', topn=2500)
# # g_list = pd.DataFrame(g).loc[:,[0]].T.values.tolist()[0]
# # print("Marshall syndrome" in g_list)
# # lists.append(g_list)

# h = model.wv.most_similar('HP:0000520', topn=2500)
# h_list = pd.DataFrame(h).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in h_list)
# lists.append(h_list)

# i = model.wv.most_similar('HP:0011800', topn=2500)
# i_list = pd.DataFrame(h).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in i_list)
# lists.append(i_list)


# set.intersection(*map(set,lists))
# Out:
# [('Stickler syndrome', 0.8238318562507629),
#  ('Stickler syndrome type 1', 0.7830736637115479),
#  ('Autosomal recessive Stickler syndrome', 0.769079864025116),
#  ('Spondyloepiphyseal dysplasia congenita', 0.7687696814537048),
#  ('STICKLER SYNDROME, TYPE II', 0.7271227240562439),
#  ('AYME-GRIPP SYNDROME; AYGRP', 0.7133471965789795),
#  ('#154780 MARSHALL SYNDROME; MRSHS', 0.7124046087265015),
#  ('Autosomal recessive distal osteolysis syndrome', 0.7121619582176208),
#  ('Pectus excavatum-macrocephaly-dysplastic nails syndrome',
#   0.7062357664108276),
#  ('Kniest dysplasia', 0.7054544687271118)]
