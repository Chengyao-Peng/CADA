# %%
import gensim
from gensim.models import Word2Vec
from node2vec import Node2Vec
import pandas as pd

model = Word2Vec.load('annotation_orpha_triples_hpo.model')
model.wv.most_similar('Marshall syndrome')
#model.wv.most_similar('Multiple congenital anomalies-hypotonia-seizures syndrome')


# lists = []


# hpo_terms = ['HP:0005280', 'HP:0000175', 'HP:0000347', 'HP:0000545', 'HP:0000463', 'HP:0003196', 'HP:0000201', 'HP:0000520', 'HP:0011800']

# for

# a = model.wv.most_similar('HP:0005280', topn=500)
# a_list = pd.DataFrame(a).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in a_list)
# lists.append(a_list)

# b = model.wv.most_similar('HP:0000175', topn=500)
# b_list = pd.DataFrame(b).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in b_list)
# lists.append(b_list)

# c = model.wv.most_similar('HP:0000347', topn=500)
# c_list = pd.DataFrame(c).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in c_list)
# lists.append(c_list)


# d = model.wv.most_similar('HP:0000545', topn=500)
# d_list = pd.DataFrame(d).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in d_list)
# lists.append(d_list)

# e = model.wv.most_similar('HP:0000463', topn=500)
# e_list = pd.DataFrame(e).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in e_list)
# lists.append(e_list)

# f = model.wv.most_similar('HP:0003196', topn=500)
# f_list = pd.DataFrame(f).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in f_list)
# lists.append(f_list)

# # g = model.wv.most_similar('HP:0000201', topn=2500)
# # g_list = pd.DataFrame(g).loc[:,[0]].T.values.tolist()[0]
# # print("Marshall syndrome" in g_list)
# # lists.append(g_list)

# h = model.wv.most_similar('HP:0000520', topn=500)
# h_list = pd.DataFrame(h).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in h_list)
# lists.append(h_list)

# i = model.wv.most_similar('HP:0011800', topn=500)
# i_list = pd.DataFrame(h).loc[:,[0]].T.values.tolist()[0]
# print("Marshall syndrome" in i_list)
# lists.append(i_list)


# set.intersection(*map(set,lists))
# Out:
# [('Autosomal recessive Stickler syndrome', 0.781607985496521),
#  ('Stickler syndrome type 1', 0.7546806335449219),
#  ('Stickler syndrome', 0.7502635717391968),
#  ('Craniolenticulosutural dysplasia', 0.69459468126297),
#  ('Dysmorphism-pectus carinatum-joint laxity syndrome', 0.6749486923217773),
#  ('Spondyloepiphyseal dysplasia congenita', 0.6628772020339966),
#  ('Autosomal recessive distal osteolysis syndrome', 0.6589750647544861),
#  ('Tetrasomy 12p', 0.6580911874771118),
#  ('Craniofacial-deafness-hand syndrome', 0.6577470302581787),
#  ('Multiple epiphyseal dysplasia, Beighton type', 0.6553373336791992)]
