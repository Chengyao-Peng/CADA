# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_with = pd.read_excel('/home/peng/PycharmProjects/featurematch/model/withoutgene_omim_with_patients/evaluation.xlsx')
df_without = pd.read_excel('/home/peng/PycharmProjects/featurematch/model/withoutgene_omim_without_patients/evaluation.xlsx')[['rank_hpo']]

df = pd.concat([df_with, df_without], axis=1)
df['c']= np.negative(np.log(df.rank_withp/df.rank_hpo))

df.to_excel('c.xlsx', index=None)

# %%
df
# Out:
#          patient_id                                         omim_id  \
# 0    Patient:208664                            Larsen Syndrome; LRS
# 1    Patient:208659                            Larsen Syndrome; LRS
# 2    Patient:222155       Microcephaly, Primary Autosomal Recessive
# 3    Patient:222306                        Marshall Syndrome; MRSHS
# 4    Patient:222308                        Marshall Syndrome; MRSHS
# ..              ...                                             ...
# 239   Patient:51561                       Rubinstein-Taybi Syndrome
# 240   Patient:40643                Smith-Lemli-Opitz Syndrome; SLOS
# 241   Patient:47450                                  Sotos Syndrome
# 242  Patient:130011  Trichorhinophalangeal Syndrome , Type I; TRPS1
# 243   Patient:52586  Trichorhinophalangeal Syndrome , Type I; TRPS1
#
#      No.patients                                           features  \
# 0              6  Short stature,Elbow dislocation,Congenital kne...
# 1              6  Short stature,Knee dislocation,Congenital hip ...
# 2              1  Absent speech,Intellectual disability, severe,...
# 3              6  Depressed nasal bridge,Cleft palate,Micrognath...
# 4              6  Depressed nasal bridge,Cleft palate,Arthralgia...
# ..           ...                                                ...
# 239           13  Inappropriate laughter,Hypokinesia,Hypersomnia...
# 240            9  Delayed speech and language development,Short ...
# 241           24  Hypoplasia of the corpus callosum,Hydrocele te...
# 242            8  Short 3rd finger,Underdeveloped nasal alae,Abs...
# 243            8  Short hallux,Short finger,Flat nasal alae,Fine...
#
#      No.features                                      results_withp  \
# 0             13  ['Larsen Syndrome; LRS', '#108721 ATELOSTEOGEN...
# 1             16  ['Larsen Syndrome; LRS', 'SPONDYLOEPIMETAPHYSE...
# 2              3  ['Hyperphosphatasia with Mental Retardation Sy...
# 3              9  ['Marshall Syndrome; MRSHS', '275595 TRIGONOBR...
# 4             14  ['Marshall Syndrome; MRSHS', '#215150 OTOSPOND...
# ..           ...                                                ...
# 239           40  ['227210 EYEBROWS, DUPLICATION OF, WITH STRETC...
# 240           16  ['SYNPOLYDACTYLY 1', 'CLEFT PALATE, DEAFNESS, ...
# 241           18  ['Sotos Syndrome', 'Phelan-Mcdermid Syndrome; ...
# 242           14  ['Trichorhinophalangeal Syndrome , Type I; TRP...
# 243           20  ['SYNDACTYLY, TYPE III', 'ODONTOMICRONYCHIAL D...
#
#      rank_withp  rank_hpo         c
# 0             1         1 -0.000000
# 1             1         1 -0.000000
# 2           306       369  0.187212
# 3             1         2  0.693147
# 4             1         1 -0.000000
# ..          ...       ...       ...
# 239         420       218 -0.655760
# 240         211       386  0.603979
# 241           1         6  1.791759
# 242           1         3  1.098612
# 243           3        23  2.036882
#
# [244 rows x 9 columns]
