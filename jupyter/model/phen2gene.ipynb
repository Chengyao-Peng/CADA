# %%
import pandas as pd
import os
import shutil

# %%
dir_name = 'phen2gene'
if os.path.exists(dir_name):
    shutil.rmtree(dir_name)
    os.mkdir('phen2gene')
    print("Directory '%s' created" %dir_name)
else:
    os.mkdir('phen2gene')
    print("Directory '%s' created" %dir_name)

# %%
# read test patients
test_patients = pd.read_csv('patient_testing.tsv', sep = '\t', header=None)
for patient in test_patients.values.tolist():
    file_name = patient[0].split(':')[1]
    file_path = os.path.join(dir_name, file_name)
    hpos = '\n'.join(patient[3].split(','))
    with open(file_path, 'w') as f:
        f.write(hpos)
test_patients
# Out:
#                       0            1             2  \
# 0         Patient:37083  OMIM:614749  Entrez:84720
# 1        Patient:204249  OMIM:602849   Entrez:2261
# 2         Patient:29999  OMIM:615716  Entrez:93210
# 3        Patient:208664  OMIM:150250   Entrez:2317
# 4        Patient:208654  OMIM:150250   Entrez:2317
# ...                 ...          ...           ...
# 4812  Patient:berlin_10      unknown  Entrez:23476
# 4813  Patient:berlin_11      unknown   Entrez:8398
# 4814  Patient:berlin_12  OMIM:617228   Entrez:4285
# 4815  Patient:berlin_13  OMIM:615438  Entrez:51520
# 4816  Patient:berlin_14  OMIM:611093   Entrez:7991
#
#                                                       3                  4  \
# 0     HP:0003155,HP:0001263,HP:0000286,HP:0000215,HP...  Dr. Peter Krawitz
# 1     HP:0001263,HP:0001250,HP:0001249,HP:0011317,HP...   Nurulhuda Hajjir
# 2     HP:0003155,HP:0000322,HP:0000215,HP:0001249,HP...  Dr. Peter Krawitz
# 3     HP:0009836,HP:0001374,HP:0002948,HP:0001222,HP...   Stanislav Rosnev
# 4     HP:0030310,HP:0004976,HP:0011849,HP:0012758,HP...   Stanislav Rosnev
# ...                                                 ...                ...
# 4812        HP:0000047,HP:0001263,HP:0001252,HP:0007328             berlin
# 4813                              HP:0001250,HP:0000717             berlin
# 4814  HP:0001263,HP:0000508,HP:0001252,HP:0004322,HP...             berlin
# 4815  HP:0000407,HP:0001263,HP:0012447,HP:0004856,HP...             berlin
# 4816        HP:0000750,HP:0003781,HP:0010877,HP:0002317             berlin
#
#            5   6
# 0      pedia   8
# 1      pedia   5
# 2      pedia   5
# 3      pedia  13
# 4      pedia  22
# ...      ...  ..
# 4812  berlin   4
# 4813  berlin   2
# 4814  berlin   5
# 4815  berlin   7
# 4816  berlin   4
#
# [4817 rows x 7 columns]

# %%
####run phen2gene manually and save result to phen2gene/out
evaluation = []
for patient in test_patients.values.tolist():
    patient_name = patient[0].split(':')[1]
    target_gene = patient[2].split(':')[1]
    result_path = os.path.join(dir_name, 'out', dir_name, patient_name, 'output_file.associated_gene_list')
    result_pd = pd.read_csv(result_path, sep = '\t', header = 0, dtype = str)
    rank = int(result_pd.loc[result_pd['ID'] == target_gene, 'Rank'].iloc[0])
    evaluation.append([patient[0], patient[2], patient[3], rank])
    
eval_df = pd.DataFrame(evaluation, columns = ['patient_id', 'gene_id', 'features', 'rank'])
eval_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-db5a2bc11134> in <module>
#       5     target_gene = patient[2].split(':')[1]
#       6     result_path = os.path.join(dir_name, 'out', dir_name, patient_name, 'output_file.associated_gene_list')
# ----> 7     result_pd = pd.read_csv(result_path, sep = '\t', header = 0, dtype = str)
#       8     rank = int(result_pd.loc[result_pd['ID'] == target_gene, 'Rank'].iloc[0])
#       9     evaluation.append([patient[0], patient[2], patient[3], rank])
#
# ~\Anaconda3\envs\CADA\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\envs\CADA\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\Anaconda3\envs\CADA\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\Anaconda3\envs\CADA\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\Anaconda3\envs\CADA\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File phen2gene\out\phen2gene\207587\output_file.associated_gene_list does not exist: 'phen2gene\\out\\phen2gene\\207587\\output_file.associated_gene_list'
