# %%
import pandas as pd



df = pd.DataFrame(columns=['id', 'sex', 'age', 'present_hpo_id', 'present_hpo_name', 'absent_hpo_id', 'absent_hpo_name', /
                           'gene_id', 'gene_symbol', 'disease_OMIM_id', 'disease_name', 'submitter', 'created_by'])
