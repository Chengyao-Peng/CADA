# %%
import os
from CADA.paths import DATA_DIRECTORY

input_clinvar = os.path.join(DATA_DIRECTORY, 'raw', 'patients', 'clinvar', 'result.tsv')
with open(input_clinvar, 'r') as infile:
    content = infile.read().splitlines()[1:]
    patients = [x.split('\t') for x in content]
    for patient in patients:
        hpos_list = patient[3].split(',')
        features_line = ','.join([hpo_dict.get(feature, feature) for feature in hpos_list])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e36d211258af> in <module>
#       8     for patient in patients:
#       9         hpos_list = patient[3].split(',')
# ---> 10         features_line = ','.join([hpo_dict.get(feature, feature) for feature in hpos_list])
#      11         print(features_line)
#
# <ipython-input-6-e36d211258af> in <listcomp>(.0)
#       8     for patient in patients:
#       9         hpos_list = patient[3].split(',')
# ---> 10         features_line = ','.join([hpo_dict.get(feature, feature) for feature in hpos_list])
#      11         print(features_line)
#
# NameError: name 'hpo_dict' is not defined
