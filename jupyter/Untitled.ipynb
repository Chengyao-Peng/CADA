# %%
from CADA.paths import DATA_DIRECTORY,MODEL_DIRECTORY
import os

evaluation_tsv = os.path.join(MODEL_DIRECTORY, 'clinvar_test_peter', 'evaluation.tsv')
phenobot_dir = os.path.join(MODEL_DIRECTORY, 'clinvar_test_peter', 'phenobot')

for filename in os.listdir(phenobot_dir):
    print(len(os.listdir(phenobot_dir)))
# Out:
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# 489
# ...
